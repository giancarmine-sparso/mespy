# %% [markdown]
# # Test di plot_utils.py

# %%
import sys
sys.path.insert(0, "..")
from script import io_utils as io
from script import stats_utils as my
from script import plot_utils as pl

import numpy as np
import pandas as pd

# %%
df = io.load_csv("../dati_riferimento/test_misure.csv")

lunghezza = df["lunghezza_mm"].values

pl.histogram(lunghezza)
# Out:
# 0.0601560470755811
# (<Figure size 2400x1500 with 1 Axes>,
#  <Axes: title={'center': 'Istogramma'}, xlabel='Valore1', ylabel='Conteggi'>)
